# %% [markdown]
# W4A16 In các số chẵn chia hết cho 3 bé hơn 100

# %%
n = int(input())
for i in range (6,100):
    print(i)

# %% [markdown]
# W4A17 Nhập vào số nguyên dương a, in ra bảng cửu chương của a

# %%
a = int(input())

for i in range(1, 11):
    print(f"{a} x {i} = {a*i}")

# %% [markdown]
# W4A18 Nhập vào số nguyên dương a và b, in toàn bộ ước chung của a và b

# %%
a,b=map(int,inut().split())
if b < a :
    a = b
for i in range (1,a+1):
    if a%i == 0 and b %i == 0:
        print(i)

# %% [markdown]
# W4A19
# [EvenNumBers]
# Viết chương trình Python sử dụng một trong 2 loại vòng lặp for hoặc while để in ra các số
# dương chẵn nhỏ hơn hoặc bằng n (n <=1000)

# %%
n = int(input())
for i in range (2,n+1,2):
    print(i)

# %% [markdown]
# W4A20 Nhập vào một số nguyên dương n, kiểm tra xem n có phải là số dạng 2^k hay không

# %%
n = int(input())

if n <= 0:
    print("NO")
else:
    while n % 2 == 0:
        n //= 2
    
    if n == 1:
        print("YES")
    else:
        print("NO")

# %% [markdown]
# W4A21 Nhập vào số nguyên dương n, tính tổng các chữ số của n

# %%
n=int(input())
tong = 0
while n>0:
    tong= tong + n % 10
    n = n // 10
print(tong)

# %% [markdown]
# W4A22 Nhập vào số nguyên dương n, đếm xem n có bao nhiêu chữ số chẵn, bao nhiêu chữ số lẻ

# %%
n=int(input())
deml=0
demc=0
while n>0:
    if (n%10)%2==0:
        demc +=1
    else:
        deml +=1
    n = n//10
print(demc,deml)

# %% [markdown]
# W4A23
# Nhập n
# Cho S(k) = 1 + 2 + 3 + … + k
# Tìm k sao cho S(k) lớn nhất nhưng nhỏ hơn n

# %%
n=int(input())
tong = 0
i=0
while tong<n:
    i += 1
    tong = (i+1)*i//2
print(i-1)

# %% [markdown]
# W4A24 Nhập vào số nguyên dương A, tìm n nhỏ nhất sao cho
# 1 + 1/2 + 1/3 + 1/4 + ... + 1/n > A

# %%
A = int(input())

S = 0
n = 0

while S <= A:
    n += 1
    S += 1 / n

print(n)

# %% [markdown]
# W4A25
# Nhập vào một dãy số nguyên, ngưng nhập khi người dùng nhập -1.
# Sau khi nhập xong, in số lớn nhất, số nhỏ nhất trong những số vừa nhập

# %%
_max = 0
_min = 9999999999999999999999
while True:
    a = int(input())
    if a == -1:
        print(_max,_min)
    else:
        if a > _max:
            _max = a
        if a < _min:
            _min = a

# %% [markdown]
# W4A26
# [Fibonaci1]
# Dãy số fibonacci là dãy số được định nghĩa như sau: 1, 1, 2, 3, 5, 8, 13,... với số kế tiếp sẽ
# bằng tổng hai số trước đó
# Nhập vào số nguyên dương A, hãy tìm số trong dãy số fibonacci lớn nhất nhưng không vượt
# quá A

# %%
A = int(input())
a, b = 1, 1
while b <= A:
    a, b = b, a + b
print(a)

# %% [markdown]
# W4A27
# Nhập vào một chuỗi, hãy đếm xem trong chuỗi có bao nhiêu từ (quy định là chuỗi không có
# ký tự đặc biệt, không số, không có dấu câu, chỉ có ký tự chhữ và khoảng trắng)
# Dùng cách: for trên index; KHÔNG dùng hàm split(), len()

# %%
s = input()
count = 0
i = 0
for _ in s:
    if s[i] != ' ' and (i == 0 or s[i-1] == ' '):
        count += 1
    i += 1
print(count)

# %% [markdown]
# W4A28
# Nhập vào một chuỗi, hãy in từ đầu tiên trong chuỗi
# Dùng cách: for trên index; KHÔNG dùng hàm split()

# %%
s = input()
bdau=0
for i in range(len(s)):
    if s[i] != ' ':
        bdau = i
        break
for i in range(bdau, len(s)):
    if s[i] == ' ':
        break
    print(s[i], end='')

# %% [markdown]
# W4A29
# Cho một chuỗi chỉ gồm các ký tự chữ cái thường và chữ cái hoa, hãy đổi ký tự hoa thành
# thường và thường thành hoa.

# %%
s = input()
result = ""
for i in range(len(s)):
    if 'a' <= s[i] <= 'z':
        result += chr(ord(s[i]) - 32)
    elif 'A' <= s[i] <= 'Z':
        result += chr(ord(s[i]) + 32)
print(result)

# %% [markdown]
# W4A30
# Nhập vào một chuỗi có dạng 3 số nguyên, mỗi số nguyên cách nhau một dấu phẩy, hãy tính
# tổng 3 số nguyên đó
# VD:
# Nhập: 3, 12, 15
# Tổng: 30

# %%
s = input()

total = 0
num = ""

for i in range(len(s)):
    if s[i] == ',':
        total += int(num)
        num = ""
    elif s[i] != ' ':
        num += s[i]

# cộng số cuối
total += int(num)

print(total)

# %% [markdown]
# W4A31
# Nhập vào một chuỗi, hãy đếm xem trong chuỗi có bao nhiêu ký tự in hoa, bao nhiêu ký tự in
# thường, bao nhiêu

# %%
s = input()

inhoa = 0
inthuong = 0
so = 0

for i in range(len(s)):
    if 'A' <= s[i] <= 'Z':
        inhoa += 1
    elif 'a' <= s[i] <= 'z':
        inthuong += 1
    else:
        so += 1

print(inhoa)
print(inthuong)
print(so)
